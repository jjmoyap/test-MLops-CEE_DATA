# %%
# Instalación e importación de librerías
# %pip install pandas matplotlib seaborn --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os


# Cambiar al directorio raíz del proyecto
os.chdir("..")  # Ajustar si el notebook está en /notebooks
print("Directorio actual:", os.getcwd())


# Cargar dataset limpio generado por Data Engineer
df = pd.read_pickle("data/intermediate/df.pkl")
print("Dimensiones del dataset:", df.shape)
df.head()


# Exploración general de variables
print("\nInformación general del dataset:")
display(df.info())

print("\nNúmero de duplicados:", df.duplicated().sum())
print("\nValores nulos por columna:")
print(df.isnull().sum())


# Distribución de la variable objetivo 'Performance'
plt.figure(figsize=(7,4))
ax = sns.countplot(data=df, x='Performance', order=df['Performance'].value_counts().index)
plt.title('Distribución de Performance (conteos)')
plt.xticks(rotation=45)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', xy=(p.get_x() + p.get_width()/2, height),
                xytext=(0,5), textcoords='offset points', ha='center', va='bottom')
plt.show()


# Distribución de variables categóricas
categorical_cols = ['Gender', 'Caste', 'coaching', 'time',
                    'Class_ten_education', 'twelve_education', 'medium',
                    'Father_occupation', 'Mother_occupation']

for col in categorical_cols:
    plt.figure(figsize=(7,4))
    order = df[col].value_counts().index
    ax = sns.countplot(data=df, x=col, order=order)
    plt.title(f'Conteo por {col}')
    plt.xticks(rotation=45)
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height}', xy=(p.get_x() + p.get_width()/2, height),
                    xytext=(0,5), textcoords='offset points', ha='center', va='bottom')
    plt.show()


# Histograma y estadísticas de Academic_Score
if 'Academic_Score' in df.columns:
    plt.figure(figsize=(7,4))
    sns.histplot(df['Academic_Score'], bins=10)
    plt.title('Distribución de Academic_Score')
    plt.show()
    print("Estadísticas descriptivas de Academic_Score:")
    display(df['Academic_Score'].describe())


# Matriz de correlación de variables numéricas
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
if numeric_cols:
    corr = df[numeric_cols].corr()
    plt.figure(figsize=(10,8))
    sns.heatmap(corr, annot=True, fmt=".2f")
    plt.title('Matriz de correlación de variables numéricas')
    plt.show()


# Distribuciones y relaciones adicionales
if 'Academic_Score' in df.columns:
    plt.figure(figsize=(7,4))
    sns.boxplot(data=df, x='Performance', y='Academic_Score')
    plt.title('Academic_Score por Performance')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Directorio actual: C:\Users\Jorge Moya\Documents\Academic\I.T.E.S.M\M.E. Inteligencia Artificial Aplicada\4to Trimestre\Operaciones de aprendizaje automático\Tareas o Trabajos\ml-CEE_DATA-project
# Dimensiones del dataset: (622, 25)
#
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 622 entries, 0 to 665
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Performance               622 non-null    object
#  1   Gender                    622 non-null    object
#  2   Caste                     622 non-null    object
#  3   coaching                  622 non-null    object
#  4   time                      622 non-null    object
#  5   Class_ten_education       622 non-null    object
#  6   twelve_education          622 non-null    object
#  7   medium                    622 non-null    object
#  8   Class_ X_Percentage       622 non-null    object
#  9   Class_XII_Percentage      622 non-null    object
#  10  Father_occupation         622 non-null    object
#  11  Mother_occupation         622 non-null    object
#  12  Performance_grouped       622 non-null    object
#  13  Class_X_num               622 non-null    float64
#  14  Class_XII_num             622 non-null    float64
#  15  Academic_Score            622 non-null    float64
#  16  Gender_freq               622 non-null    float64
#  17  Caste_freq                622 non-null    float64
#  18  coaching_freq             622 non-null    float64
#  19  time_freq                 622 non-null    float64
#  20  Class_ten_education_freq  622 non-null    float64
#  21  twelve_education_freq     622 non-null    float64
#  22  medium_freq               622 non-null    float64
#  23  Father_occupation_freq    622 non-null    float64
#  24  Mother_occupation_freq    622 non-null    float64
# dtypes: float64(12), object(13)
# memory usage: 126.3+ KB
# None
# Número de duplicados: 122
#
# Valores nulos por columna:
# Performance                 0
# Gender                      0
# Caste                       0
# coaching                    0
# time                        0
# Class_ten_education         0
# twelve_education            0
# medium                      0
# Class_ X_Percentage         0
# Class_XII_Percentage        0
# Father_occupation           0
# Mother_occupation           0
# Performance_grouped         0
# Class_X_num                 0
# Class_XII_num               0
# Academic_Score              0
# Gender_freq                 0
# Caste_freq                  0
# coaching_freq               0
# time_freq                   0
# Class_ten_education_freq    0
# twelve_education_freq       0
# medium_freq                 0
# Father_occupation_freq      0
# Mother_occupation_freq      0
# dtype: int64
# Estadísticas descriptivas de Academic_Score:
# count    622.000000
# mean       3.536174
# std        0.664775
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        4.000000
# Name: Academic_Score, dtype: float64
